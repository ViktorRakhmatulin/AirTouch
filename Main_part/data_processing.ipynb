# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
f = np.loadtxt('./exp1/distance_vel_time1.txt')

# %%
time = f[:,2]
distance = f[:,0]
vel = f[:,1]

# %%
plt.plot(time,distance)

# %%
plt.plot(time,vel)
