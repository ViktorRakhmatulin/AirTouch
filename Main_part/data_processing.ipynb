# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
f = np.loadtxt('./exp1/distance_check.txt')

# %%
distance = f[:,1]

# %%
distance.std()
# Out:
# 0.03636580645725726

# %%
(distance-0.3).mean()
# Out:
# -0.056518518518518496

# %%
plt.plot(time,distance)
plt.xlim([27.7,36])
plt.hlines([0.2],27.7,36,['r'])

# %%
plt.plot(time,vel)
plt.xlim([27.7,36])
plt.ylim([0,2])
# Out:
# (0.0, 2.0)

# %%
# Out:
# (25.0, 40.0)
